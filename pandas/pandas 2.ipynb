# %%
# inporting numpy and pandas 
import numpy as np
import pandas as pd

# %%
zomato_data = pd.read_csv('zomato.csv')   # importing csv file from device

# %%
zomato_data
# Out:
#       Unnamed: 0  Restaurant ID           Restaurant Name  Country Code  \
# 0              0        6317637          Le Petit Souffle           168
# 1              1        6304287          Izakaya Kikufuji           162
# 2              2        6300002    Heat - Edsa Shangri-La           162
# 3              3        6318506                      Ooma           162
# 4              4        6314302               Sambo Kojin           162
# ...          ...            ...                       ...           ...
# 9546        9546        5915730              NamlÛ± Gurme           208
# 9547        9547        5908749             Ceviz AÛôacÛ±           208
# 9548        9548        5915807                     Huqqa           208
# 9549        9549        5916112              Aôôk Kahve           208
# 9550        9550        5927402  Walter's Coffee Roastery           208
#
#                   City                                            Address  \
# ...

# %%
zomato_data.head()
# Out:
#    Unnamed: 0  Restaurant ID         Restaurant Name  Country Code  \
# 0           0        6317637        Le Petit Souffle           168
# 1           1        6304287        Izakaya Kikufuji           162
# 2           2        6300002  Heat - Edsa Shangri-La           162
# 3           3        6318506                    Ooma           162
# 4           4        6314302             Sambo Kojin           162
#
#                City                                            Address  \
# 0       Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# 1       Makati City  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Mandaluyong City  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Mandaluyong City  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Mandaluyong City  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# ...

# %%
zomato_data.head(10)
# Out:
#    Unnamed: 0  Restaurant ID                           Restaurant Name  \
# 0           0        6317637                          Le Petit Souffle
# 1           1        6304287                          Izakaya Kikufuji
# 2           2        6300002                    Heat - Edsa Shangri-La
# 3           3        6318506                                      Ooma
# 4           4        6314302                               Sambo Kojin
# 5           5       18189371                              Din Tai Fung
# 6           6        6300781                                Buffet 101
# 7           7        6301290                                   Vikings
# 8           8        6300010  Spiral - Sofitel Philippine Plaza Manila
# 9           9        6314987                                  Locavore
#
#    Country Code              City  \
# 0           168       Makati City
# 1           162       Makati City
# 2           162  Mandaluyong City
# 3           162  Mandaluyong City
# ...

# %%
zomato_data.tail()
# Out:
#       Unnamed: 0  Restaurant ID           Restaurant Name  Country Code  \
# 9546        9546        5915730              NamlÛ± Gurme           208
# 9547        9547        5908749             Ceviz AÛôacÛ±           208
# 9548        9548        5915807                     Huqqa           208
# 9549        9549        5916112              Aôôk Kahve           208
# 9550        9550        5927402  Walter's Coffee Roastery           208
#
#            City                                            Address  \
# 9546  ÛÁstanbul  Kemankeô Karamustafa Paôa Mahallesi, RÛ±htÛ±...
# 9547  ÛÁstanbul  Koôuyolu Mahallesi, Muhittin íìstí_ndaÛô Cadd...
# 9548  ÛÁstanbul  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...
# 9549  ÛÁstanbul  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...
# 9550  ÛÁstanbul  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...
#
#          Locality        Locality Verbose  Longitude   Latitude  ...  \
# ...

# %%
zomato_data.tail(10)
# Out:
#       Unnamed: 0  Restaurant ID           Restaurant Name  Country Code  \
# 9541        9541        5905215           Emirgan Sí_tiô           208
# 9542        9542        5926979            Leman Kí_ltí_r           208
# 9543        9543        5916085              Dem Karakí_y           208
# 9544        9544        5915547     Karakí_y Gí_llí_oÛôlu           208
# 9545        9545        5915054                  Baltazar           208
# 9546        9546        5915730              NamlÛ± Gurme           208
# 9547        9547        5908749             Ceviz AÛôacÛ±           208
# 9548        9548        5915807                     Huqqa           208
# 9549        9549        5916112              Aôôk Kahve           208
# 9550        9550        5927402  Walter's Coffee Roastery           208
#
#            City                                            Address  \
# 9541  ÛÁstanbul  Emirgan Mahallesi, SakÛ±p SabancÛ± Caddesi, No...
# ...

# %%
zomato_data.head(2)
# Out:
#    Unnamed: 0  Restaurant ID   Restaurant Name  Country Code         City  \
# 0           0        6317637  Le Petit Souffle           168  Makati City
# 1           1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#    ...          Currency  Has Table booking Has Online delivery  \
# 0  ...  Botswana Pula(P)                Yes                  No
# 1  ...  Botswana Pula(P)                Yes                  No
#
# ...

# %%
zomato_data['Country Code']      # to get a single column
# Out:
# 0       168
# 1       162
# 2       162
# 3       162
# 4       162
#        ...
# 9546    208
# 9547    208
# 9548    208
# 9549    208
# 9550    208
# Name: Country Code, Length: 9551, dtype: int64

# %%
zomato_data['Country Code'][0]   # getting value by index no
# Out:
# 162

# %%
zomato_data['Country Code'][0] = 168   # here the warning is for not to change the data
# Out:
# C:\Users\chand\AppData\Local\Temp\ipykernel_18092\3756715386.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato_data['Country Code'][0] = 168   # here the warning is for not to change the data

# %%
zomato_data['Country Code'][0]    # here the data will be changed
# Out:
# 168

# %%
zomato_data.to_csv('zomato.csv')    # by running this code data will be changed to csv file
